# %% [markdown]
# # 1.- Import the necessary libraries.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 2.- Load the we_fn_use_c_marketing_customer_value_analysis.csv into the variable customer_df

# %%
customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')

# %% [markdown]
# # 3.- Load the we_fn_use_c_marketing_customer_value_analysis.csv into the variable customer_df

# %%
display(customer_df.shape)
display(customer_df.head())
display(customer_df.isnull().sum())
display(customer_df.dtypes)
# Out:
# (9134, 24)
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %% [markdown]
# # 4.- Rename the columns so they follow the PE8 (snake case) (lower_case_with_underscores)

# %%
customer_df.columns=[e.lower().replace(' ', '_') for e in customer_df.columns] 
display(customer_df.head())
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   months_since_policy_inception number_of_open_complaints  number_of_policies  \
# ...

# %% [markdown]
# # 5.- Change effective to date column to datetime format.

# %%
customer_df['effective_to_date'] = pd.to_datetime(customer_df['effective_to_date'])
customer_df.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0        2011-02-24         Employed      F   56274  ...
# 1        2011-01-31       Unemployed      F       0  ...
# 2        2011-02-19         Employed      F   48767  ...
# 3        2011-01-20       Unemployed      M       0  ...
# 4        2011-02-03         Employed      M   43836  ...
#
#   months_since_policy_inception number_of_open_complaints  number_of_policies  \
# ...

# %% [markdown]
# # 6.- Create a new dataframe using only the numerical data called numerical_df. Use this for the following questions.

# %%
numericals = customer_df.select_dtypes(np.number)
numericals.head()
# Out:
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    months_since_last_claim  months_since_policy_inception  \
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44
#
#    number_of_open_complaints  number_of_policies  total_claim_amount
# 0                          0                   1          384.811147
# 1                          0                   8         1131.464935
# ...

# %% [markdown]
# # 7.- Define a function that differentiates between continuous and discrete variables. Hint: The number of unique values might be useful. Store continuous data into a continuous_df variable and do the same for discrete_df

# %%
numericals.isnull().sum()/len(numericals)
# Out:
# customer_lifetime_value          0.0
# income                           0.0
# monthly_premium_auto             0.0
# months_since_last_claim          0.0
# months_since_policy_inception    0.0
# number_of_open_complaints        0.0
# number_of_policies               0.0
# total_claim_amount               0.0
# dtype: float64

# %%
display(numericals['customer_lifetime_value'].nunique())
display(numericals['income'].nunique())
display(numericals['monthly_premium_auto'].nunique())
display(numericals['months_since_last_claim'].nunique())
display(numericals['months_since_policy_inception'].nunique())
display(numericals['number_of_open_complaints'].nunique())
display(numericals['number_of_policies'].nunique())
display(numericals['total_claim_amount'].nunique())
# Out:
# 8041
# 5694
# 202
# 36
# 100
# 6
# 9
# 5106

# %%
             
def differentiate_variables(numerical_customer_df):
    continuous_vars = []
    discrete_vars = []
    for col in numerical_customer_df.columns:
        num_unique = numerical_customer_df[col].nunique()
        if num_unique > 250:
            continuous_vars.append(col)
        else:
            discrete_vars.append(col)
    return print('Those are continuous variables', continuous_vars), print('Those are discrete variables', discrete_vars)

# %%
# Separate the data into continuous and discrete variables
continuous_vars, discrete_vars = differentiate_variables(numericals)
# Out:
# Those are continuous variables ['customer_lifetime_value', 'income', 'total_claim_amount']
# Those are discrete variables ['monthly_premium_auto', 'months_since_last_claim', 'months_since_policy_inception', 'number_of_open_complaints', 'number_of_policies']

# %%
continuous_df= numericals[['customer_lifetime_value', 'income', 'total_claim_amount']]
discrete_df= numericals[['monthly_premium_auto', 'months_since_last_claim', 'months_since_policy_inception', 'number_of_open_complaints', 'number_of_policies']]

# %% [markdown]
# # 8.- Plot a correlation matrix, comment what you see.

# %%
correlations_matrix = continuous_df.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# %%
correlations_matrix = discrete_df.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# %%
correlations_matrix = numericals.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# %% [raw]
# # There isn't a hight correlation between the variables

# %% [markdown]
# # 9,- Create a function to plot every discrete variable. Do the same with the continuous variables (Be Careful, you may need to change the plot type to one better suited for continuous data!)

# %%
continuous_df['customer_lifetime_value'].hist(bins=100)
plt.show()
continuous_df['income'].hist(bins=100)
plt.show()
continuous_df['total_claim_amount'].hist(bins=100)
plt.show()

# %%
discrete_df['monthly_premium_auto'].hist(bins=100)
plt.show()
discrete_df['months_since_last_claim'].hist(bins=100)
plt.show()
discrete_df['months_since_policy_inception'].hist(bins=100)
plt.show()
discrete_df['number_of_open_complaints'].hist(bins=100)
plt.show()
discrete_df['number_of_policies'].hist(bins=100)
plt.show()

# %% [markdown]
# # 10.- Comment what you can see in the plots.

# %%
# In general, we don't see that much normal distribution across the variables

# %% [markdown]
# # 11.- Look for outliers in the continuous variables. (HINT: There’s a good plot to do that!)

# %%
sns.boxplot(y=discrete_df['monthly_premium_auto'])
plt.show()
sns.boxplot(y=discrete_df['months_since_last_claim'])
plt.show()
sns.boxplot(y=discrete_df['months_since_policy_inception'])
plt.show()
sns.boxplot(y=discrete_df['number_of_open_complaints'])
plt.show()
sns.boxplot(y=discrete_df['number_of_policies'])
plt.show()

# %% [markdown]
# # 12.- Did you find outliers? Comment what you will do with them. If you decide to remove them, do that now.

# %%
# There is no point to drop outliers

# %% [markdown]
# # 13.- Check all columns for NaN values. Decide what (if anything) you will need to do with them, do that now.

# %%
numericals.isna().sum()
# Out:
# customer_lifetime_value          0
# income                           0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# total_claim_amount               0
# dtype: int64

# %% [markdown]
# # 14.- Save the numerical_df to csv as numerical.csv You will use this file again this week.

# %%
numericals.to_csv('numerical.csv', index=False)
